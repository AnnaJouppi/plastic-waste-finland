# %%
# Suomen pakkausjätteen määrä per henkilö visualisoituna vuosilta 2014-2023, poislukien koronavuodet 2019-2021. Vuodet poistetty, koska
# pakkausjätteen määrä nousi silloin jyrkästi. Ennustus vuosille 2024-2026.

import pandas as pd

# %%
plasticdata = pd.read_csv("data/env_waspac_page_linear.csv")

# tehdään kopio jotta ei tehdä muutoksia alkuperäiseen
plastic_copy = plasticdata.copy()

plastic_copy = plastic_copy.rename(columns= {
    "geo": "Country",
    "unit" : "Unit",
    "TIME_PERIOD" : "Year",
    "OBS_VALUE" : "Waste kg per person",
    "waste" : "Waste category",
    "wst_oper" : "Operation"
})

plastic_copy
# Out:
#                 DATAFLOW        LAST UPDATE    freq     Waste category  \
# 0  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 1  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 2  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 3  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 4  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 5  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 6  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 7  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 8  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
# 9  ESTAT:ENV_WASPAC(1.0)  11/05/26 23:00:00  Annual  Plastic packaging
#
#          Operation                  Unit  Country  Year  Waste kg per person  \
# 0  Waste generated  Kilograms per capita  Finland  2014                21.38
# 1  Waste generated  Kilograms per capita  Finland  2015                21.27
# 2  Waste generated  Kilograms per capita  Finland  2016                22.36
# 3  Waste generated  Kilograms per capita  Finland  2017                23.66
# 4  Waste generated  Kilograms per capita  Finland  2018                24.52
# 5  Waste generated  Kilograms per capita  Finland  2019                24.22
# 6  Waste generated  Kilograms per capita  Finland  2020                28.41
# 7  Waste generated  Kilograms per capita  Finland  2021                29.94
# 8  Waste generated  Kilograms per capita  Finland  2022                28.94
# 9  Waste generated  Kilograms per capita  Finland  2023                28.49
#
#    OBS_FLAG  CONF_STATUS
# 0       NaN          NaN
# 1       NaN          NaN
# 2       NaN          NaN
# 3       NaN          NaN
# 4       NaN          NaN
# 5       NaN          NaN
# 6       NaN          NaN
# 7       NaN          NaN
# 8       NaN          NaN
# 9       NaN          NaN

# %%
# clean and prepare the data
finland = plastic_copy[plastic_copy["Country"] == "Finland"]
finland = finland[["Year", "Waste kg per person"]].dropna()
finland_not_corona = finland[(finland["Year"] < 2020) | (finland["Year"] > 2021)]

# %%
# Visualize the trend
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.bar(finland_not_corona["Year"], finland_not_corona["Waste kg per person"], label="Historical data")

# Predicted data
plt.bar(future_years.flatten(), predictions, color="orange", label="Predictions (2024–2026)")
plt.title("Plastic packaging waste per capita in Finland")
plt.xlabel("Year")
plt.ylabel("Waste kg per person")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# reshape(turns the 1D array into a 2D array)
x = finland_not_corona["Year"].values.reshape(-1,1)
y = finland_not_corona["Waste kg per person"].values

model = LinearRegression()
model.fit(x, y)

# you are training your model.
# You’re telling it:

# “Here are the input values (x), and here are the correct answers (y). Learn the relationship between them.”

# So the model looks for a pattern that best connects your inputs (x) to outputs (y).
# In linear regression, that means it tries to find the best-fitting line:

# y=a*x+b
# y=a*x+b
# where a (slope) and b (intercept) are what the model learns during .fit().

# So when you call model.fit(x, y), the model learns:
# “Given a year, what’s the typical plastic waste per person?”

# predict for next few years
# uses the learned line or curve to estimate what the target value 
# (in your case, waste per person) would be for those future years (2024–2026).
future_years = np.array([2024, 2025, 2026]).reshape(-1,1)

# This is the machine learning model making predictions.
predictions = model.predict(future_years)

#.flatten()
# This turns your 2D array back into 1D

plt.figure(figsize=(6, 6))
plt.bar(future_years.flatten(), predictions)
plt.title("Predicted Plastic packaging waste per capita in Finland")
plt.xlabel("Year")
plt.ylabel("Waste kg per person")
plt.show()

for year, pred in zip(future_years.flatten(), predictions):
    print(f"Predicted waste in {year}: {pred:.2f} kg per person")
# Out:
# Predicted waste in 2024: 29.75 kg per person
# Predicted waste in 2025: 30.65 kg per person
# Predicted waste in 2026: 31.55 kg per person
